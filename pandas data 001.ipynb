# %%
import pandas as pd; import numpy as np
import matplotlib as plt

# %%
games=pd.read_csv("vgsalesglobale.csv")

# %%
games.head(3)
# Out:
#                 Name Platform  Year_of_Release     Genre Publisher  NA_Sales  \
# 0         Wii Sports      Wii           2006.0    Sports  Nintendo     41.36
# 1  Super Mario Bros.      NES           1985.0  Platform  Nintendo     29.08
# 2     Mario Kart Wii      Wii           2008.0    Racing  Nintendo     15.68
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0     28.96      3.77         8.45         82.53          76.0          51.0
# 1      3.58      6.81         0.77         40.24           NaN           NaN
# 2     12.76      3.79         3.29         35.52          82.0          73.0
#
#    User_Score  User_Count Developer Rating
# 0         8.0       322.0  Nintendo      E
# 1         NaN         NaN       NaN    NaN
# 2         8.3       709.0  Nintendo      E

# %%
games.shape
# Out:
# (16719, 16)

# %%
games=pd.read_csv("vgsalesglobale.csv", index_col="Name")
games.head()
# Out:
#                          Platform  Year_of_Release         Genre Publisher  \
# Name
# Wii Sports                    Wii           2006.0        Sports  Nintendo
# Super Mario Bros.             NES           1985.0      Platform  Nintendo
# Mario Kart Wii                Wii           2008.0        Racing  Nintendo
# Wii Sports Resort             Wii           2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                   41.36     28.96      3.77         8.45
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.68     12.76      3.79         3.29
# Wii Sports Resort            15.61     10.93      3.28         2.95
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales  Critic_Score  Critic_Count  \
# Name
# ...

# %%
games.tail()
# Out:
#                               Platform  Year_of_Release       Genre  \
# Name
# Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# LMA Manager 2007                  X360           2006.0      Sports
# Haitaka no Psychedelica            PSV           2016.0   Adventure
# Spirits & Spells                   GBA           2003.0    Platform
# Winning Post 8 2016                PSV           2016.0  Simulation
#
#                                   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# Samurai Warriors: Sanada Maru    Tecmo Koei      0.00      0.00      0.01
# LMA Manager 2007                Codemasters      0.00      0.01      0.00
# Haitaka no Psychedelica        Idea Factory      0.00      0.00      0.01
# Spirits & Spells                    Wanadoo      0.01      0.00      0.00
# Winning Post 8 2016              Tecmo Koei      0.00      0.00      0.01
#
#                                Other_Sales  Global_Sales  Critic_Score  \
# Name
# ...

# %%
len(games)
# Out:
# 16719

# %%
games.shape
# Out:
# (16719, 15)

# %%
games.dtypes
# Out:
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
games.head(1)
# Out:
#            Platform  Year_of_Release   Genre Publisher  NA_Sales  EU_Sales  \
# Name
# Wii Sports      Wii           2006.0  Sports  Nintendo     41.36     28.96
#
#             JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# Name
# Wii Sports      3.77         8.45         82.53          76.0          51.0
#
#             User_Score  User_Count Developer Rating
# Name
# Wii Sports         8.0       322.0  Nintendo      E

# %%
games.iloc[299]
# Out:
# Platform                N64
# Year_of_Release      1997.0
# Genre               Shooter
# Publisher          Nintendo
# NA_Sales               2.78
# EU_Sales               0.58
# JP_Sales               0.64
# Other_Sales            0.04
# Global_Sales           4.03
# Critic_Score            NaN
# Critic_Count            NaN
# User_Score              NaN
# User_Count              NaN
# Developer               NaN
# Rating                  NaN
# Name: Star Fox 64, dtype: object

# %%
games.loc["Pokemon Red/Pokemon Blue"]
# Out:
# Platform                     GB
# Year_of_Release          1996.0
# Genre              Role-Playing
# Publisher              Nintendo
# NA_Sales                  11.27
# EU_Sales                   8.89
# JP_Sales                  10.22
# Other_Sales                 1.0
# Global_Sales              31.37
# Critic_Score                NaN
# Critic_Count                NaN
# User_Score                  NaN
# User_Count                  NaN
# Developer                   NaN
# Rating                      NaN
# Name: Pokemon Red/Pokemon Blue, dtype: object

# %%
games.sort_values(by="Year_of_Release").head(5)
# Out:
#                 Platform  Year_of_Release     Genre   Publisher  NA_Sales  \
# Name
# Asteroids           2600           1980.0   Shooter       Atari      4.00
# Freeway             2600           1980.0    Action  Activision      0.32
# Missile Command     2600           1980.0   Shooter       Atari      2.56
# Boxing              2600           1980.0  Fighting  Activision      0.72
# Ice Hockey          2600           1980.0    Sports  Activision      0.46
#
#                  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# Name
# Asteroids            0.26       0.0         0.05          4.31           NaN
# Freeway              0.02       0.0         0.00          0.34           NaN
# Missile Command      0.17       0.0         0.03          2.76           NaN
# Boxing               0.04       0.0         0.01          0.77           NaN
# Ice Hockey           0.03       0.0         0.01          0.49           NaN
#
# ...

# %%
games.sort_values(by="Year_of_Release",ascending=False ).head(5)
# Out:
#                                                  Platform  Year_of_Release  \
# Name
# Imagine: Makeup Artist                                 DS           2020.0
# Phantasy Star Online 2 Episode 4: Deluxe Package      PS4           2017.0
# Brothers Conflict: Precious Baby                      PSV           2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package      PSV           2017.0
# Winning Post 8 2016                                   PSV           2016.0
#
#                                                          Genre     Publisher  \
# Name
# Imagine: Makeup Artist                              Simulation       Ubisoft
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Brothers Conflict: Precious Baby                        Action  Idea Factory
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Winning Post 8 2016                                 Simulation    Tecmo Koei
#
# ...

# %%
games.sort_values(by="Year_of_Release",ascending=True ).head(5)
# Out:
#                 Platform  Year_of_Release     Genre   Publisher  NA_Sales  \
# Name
# Asteroids           2600           1980.0   Shooter       Atari      4.00
# Freeway             2600           1980.0    Action  Activision      0.32
# Missile Command     2600           1980.0   Shooter       Atari      2.56
# Boxing              2600           1980.0  Fighting  Activision      0.72
# Ice Hockey          2600           1980.0    Sports  Activision      0.46
#
#                  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# Name
# Asteroids            0.26       0.0         0.05          4.31           NaN
# Freeway              0.02       0.0         0.00          0.34           NaN
# Missile Command      0.17       0.0         0.03          2.76           NaN
# Boxing               0.04       0.0         0.01          0.77           NaN
# Ice Hockey           0.03       0.0         0.01          0.49           NaN
#
# ...

# %%
games.sort_values(by=["Year_of_Release","Genre"], ascending=False ).head(5)
# Out:
#                                                  Platform  Year_of_Release  \
# Name
# Imagine: Makeup Artist                                 DS           2020.0
# Phantasy Star Online 2 Episode 4: Deluxe Package      PS4           2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package      PSV           2017.0
# Brothers Conflict: Precious Baby                      PSV           2017.0
# Sid Meier's Civilization VI                            PC           2016.0
#
#                                                          Genre  \
# Name
# Imagine: Makeup Artist                              Simulation
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing
# Brothers Conflict: Precious Baby                        Action
# Sid Meier's Civilization VI                           Strategy
#
#                                                              Publisher  \
# Name
# ...

# %%
games.sort_index().head()
# Out:
#                             Platform  Year_of_Release         Genre  \
# Name
#  Beyblade Burst                  3DS           2016.0  Role-Playing
#  Fire Emblem Fates               3DS           2015.0  Role-Playing
#  Frozen: Olaf's Quest             DS           2013.0      Platform
#  Frozen: Olaf's Quest            3DS           2013.0      Platform
#  Haikyu!! Cross Team Match!      3DS           2016.0     Adventure
#
#                                               Publisher  NA_Sales  EU_Sales  \
# Name
#  Beyblade Burst                                   FuRyu      0.00      0.00
#  Fire Emblem Fates                             Nintendo      0.81      0.23
#  Frozen: Olaf's Quest        Disney Interactive Studios      0.21      0.26
#  Frozen: Olaf's Quest        Disney Interactive Studios      0.27      0.27
#  Haikyu!! Cross Team Match!          Namco Bandai Games      0.00      0.00
#
#                              JP_Sales  Other_Sales  Global_Sales  \
# Name
# ...

# %%
games["Publisher"]
# Out:
# Name
# Wii Sports                           Nintendo
# Super Mario Bros.                    Nintendo
# Mario Kart Wii                       Nintendo
# Wii Sports Resort                    Nintendo
# Pokemon Red/Pokemon Blue             Nintendo
#                                      ...
# Samurai Warriors: Sanada Maru      Tecmo Koei
# LMA Manager 2007                  Codemasters
# Haitaka no Psychedelica          Idea Factory
# Spirits & Spells                      Wanadoo
# Winning Post 8 2016                Tecmo Koei
# Name: Publisher, Length: 16719, dtype: object

# %%
games["Publisher"].head(10)
# Out:
# Name
# Wii Sports                   Nintendo
# Super Mario Bros.            Nintendo
# Mario Kart Wii               Nintendo
# Wii Sports Resort            Nintendo
# Pokemon Red/Pokemon Blue     Nintendo
# Tetris                       Nintendo
# New Super Mario Bros.        Nintendo
# Wii Play                     Nintendo
# New Super Mario Bros. Wii    Nintendo
# Duck Hunt                    Nintendo
# Name: Publisher, dtype: object

# %%
games.head(5)
# Out:
#                          Platform  Year_of_Release         Genre Publisher  \
# Name
# Wii Sports                    Wii           2006.0        Sports  Nintendo
# Super Mario Bros.             NES           1985.0      Platform  Nintendo
# Mario Kart Wii                Wii           2008.0        Racing  Nintendo
# Wii Sports Resort             Wii           2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                   41.36     28.96      3.77         8.45
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.68     12.76      3.79         3.29
# Wii Sports Resort            15.61     10.93      3.28         2.95
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales  Critic_Score  Critic_Count  \
# Name
# ...

# %%
games[games["Genre"]=="Action"]
# Out:
#                                   Platform  Year_of_Release   Genre  \
# Name
# Grand Theft Auto V                     PS3           2013.0  Action
# Grand Theft Auto: San Andreas          PS2           2004.0  Action
# Grand Theft Auto V                    X360           2013.0  Action
# Grand Theft Auto: Vice City            PS2           2002.0  Action
# Grand Theft Auto III                   PS2           2001.0  Action
# ...                                    ...              ...     ...
# Metal Gear Solid V: Ground Zeroes       PC           2014.0  Action
# Carmageddon 64                         N64           1999.0  Action
# Planet Monsters                        GBA           2001.0  Action
# The Longest 5 Minutes                  PSV           2016.0  Action
# Samurai Warriors: Sanada Maru          PS3           2016.0  Action
#
#                                                       Publisher  NA_Sales  \
# Name
# ...

# %%
x=games["Genre"]=="Action"

# %%
games[x]
# Out:
#                                   Platform  Year_of_Release   Genre  \
# Name
# Grand Theft Auto V                     PS3           2013.0  Action
# Grand Theft Auto: San Andreas          PS2           2004.0  Action
# Grand Theft Auto V                    X360           2013.0  Action
# Grand Theft Auto: Vice City            PS2           2002.0  Action
# Grand Theft Auto III                   PS2           2001.0  Action
# ...                                    ...              ...     ...
# Metal Gear Solid V: Ground Zeroes       PC           2014.0  Action
# Carmageddon 64                         N64           1999.0  Action
# Planet Monsters                        GBA           2001.0  Action
# The Longest 5 Minutes                  PSV           2016.0  Action
# Samurai Warriors: Sanada Maru          PS3           2016.0  Action
#
#                                                       Publisher  NA_Sales  \
# Name
# ...

# %%
veri_2010=games["Year_of_Release"]==2010

# %%
games[veri_2010 & x]
# Out:
#                                                Platform  Year_of_Release  \
# Name
# Red Dead Redemption                                 PS3           2010.0
# Red Dead Redemption                                X360           2010.0
# God of War III                                      PS3           2010.0
# Assassin's Creed: Brotherhood                      X360           2010.0
# Assassin's Creed: Brotherhood                       PS3           2010.0
# ...                                                 ...              ...
# Dark Void                                            PC           2010.0
# Pirates PlundArrr                                   Wii           2010.0
# Shin Sangoku Musou Online: Souten Ranbu             PS3           2010.0
# Marvel Superheroes 3D: Grandmaster's Challenge      Wii           2010.0
# Monkey Madness: Island Escape                        DS           2010.0
#
#                                                  Genre  \
# Name
# ...

# %%
games[veri_2010 | x]
# Out:
#                                   Platform  Year_of_Release   Genre  \
# Name
# Kinect Adventures!                    X360           2010.0    Misc
# Grand Theft Auto V                     PS3           2013.0  Action
# Grand Theft Auto: San Andreas          PS2           2004.0  Action
# Grand Theft Auto V                    X360           2013.0  Action
# Grand Theft Auto: Vice City            PS2           2002.0  Action
# ...                                    ...              ...     ...
# Metal Gear Solid V: Ground Zeroes       PC           2014.0  Action
# Carmageddon 64                         N64           1999.0  Action
# Planet Monsters                        GBA           2001.0  Action
# The Longest 5 Minutes                  PSV           2016.0  Action
# Samurai Warriors: Sanada Maru          PS3           2016.0  Action
#
#                                                       Publisher  NA_Sales  \
# Name
# ...

# %%
veri_2015=games["Year_of_Release"]>2015
games[veri_2015]
# Out:
#                                Platform  Year_of_Release         Genre  \
# Name
# FIFA 17                             PS4           2016.0        Sports
# Pokemon Sun/Moon                    3DS           2016.0  Role-Playing
# Uncharted 4: A Thief's End          PS4           2016.0       Shooter
# Call of Duty: Infinite Warfare      PS4           2016.0       Shooter
# Battlefield 1                       PS4           2016.0       Shooter
# ...                                 ...              ...           ...
# The Longest 5 Minutes               PSV           2016.0        Action
# Strawberry Nauts                    PSV           2016.0     Adventure
# Samurai Warriors: Sanada Maru       PS3           2016.0        Action
# Haitaka no Psychedelica             PSV           2016.0     Adventure
# Winning Post 8 2016                 PSV           2016.0    Simulation
#
#                                                   Publisher  NA_Sales  \
# Name
# ...

# %%
aralık=games["Year_of_Release"].between(2000,2010)

# %%
games[aralık]
# Out:
#                                                  Platform  Year_of_Release  \
# Name
# Wii Sports                                            Wii           2006.0
# Mario Kart Wii                                        Wii           2008.0
# Wii Sports Resort                                     Wii           2009.0
# New Super Mario Bros.                                  DS           2006.0
# Wii Play                                              Wii           2006.0
# ...                                                   ...              ...
# Men in Black II: Alien Escape                          GC           2003.0
# Woody Woodpecker in Crazy Castle 5                    GBA           2002.0
# SCORE International Baja 1000: The Official Game      PS2           2008.0
# LMA Manager 2007                                     X360           2006.0
# Spirits & Spells                                      GBA           2003.0
#
# ...

# %%
sport_in_title=games.index.str.lower().str.contains("sport")

# %%
games["Global_Sales"].mean()
# Out:
# 0.5335426759974459

# %%
x=games.groupby("Genre")

# %%
x["Global_Sales"].sum()
# Out:
# Genre
# Action          1745.27
# Adventure        237.69
# Fighting         447.48
# Misc             803.18
# Platform         828.08
# Puzzle           243.02
# Racing           728.90
# Role-Playing     934.40
# Shooter         1052.94
# Simulation       390.42
# Sports          1332.00
# Strategy         174.50
# Name: Global_Sales, dtype: float64

# %%
x["Global_Sales"].sum().sort_values(ascending=False)
# Out:
# Genre
# Action          1745.27
# Sports          1332.00
# Shooter         1052.94
# Role-Playing     934.40
# Platform         828.08
# Misc             803.18
# Racing           728.90
# Fighting         447.48
# Simulation       390.42
# Puzzle           243.02
# Adventure        237.69
# Strategy         174.50
# Name: Global_Sales, dtype: float64

# %%
vs=pd.read_csv("saldırı.csv")

# %%
vs.head()
# Out:
#    Unnamed: 0        Date    Country            City  Killed  Injured  \
# 0           1  2002-01-01  Indonesia            Palu       1        0
# 1           2  2002-01-01      India       Baramulla       1        0
# 2           3  2002-01-01      India         Poshkar       2        0
# 3           4  2002-01-02      India         Rajouri       6        9
# 4           5  2002-01-02      India  Jehangir Chowk       2       25
#
#                                          Description
# 0  Four bombs explode at Christian churches and o...
# 1  Terrorists enter the home of a civilian and ki...
# 2  Two civilians are abducted from their homes th...
# 3  Three separate terror attacks in the district ...
# 4  A Muslim militant kills two and injures twenty...

# %%
vs.tail()
# Out:
#        Unnamed: 0        Date     Country       City  Killed  Injured  \
# 29359       29360  2016-07-16       Syria     Aleppo       5        9
# 29360       29361  2016-07-18       Syria     Aleppo       3       15
# 29361       29362  2016-07-18       Yemen    Mukalla      10       18
# 29362       29363  2016-07-18  Kazakhstan     Almaty       4        0
# 29363       29364  2016-07-18     Germany  Wuerzburg       0        5
#
#                                              Description
# 29359  Two brothers are two women are among five civi...
# 29360  Sunnis send rockets into a residential neighbo...
# 29361  Ten people are blown to bits by a suicide car ...
# 29362  An extremist shouting praises to Allah murders...
# 29363  A 'refugee' with an axe hacks at people on a t...

# %%
vs.shape
# Out:
# (29364, 7)

# %%
vs.dtypes
# Out:
# Unnamed: 0      int64
# Date           object
# Country        object
# City           object
# Killed          int64
# Injured         int64
# Description    object
# dtype: object

# %%
vs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29364 entries, 0 to 29363
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   29364 non-null  int64
#  1   Date         29364 non-null  object
#  2   Country      29364 non-null  object
#  3   City         29364 non-null  object
#  4   Killed       29364 non-null  int64
#  5   Injured      29364 non-null  int64
#  6   Description  29363 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.6+ MB

# %%
vs.isnull()
# Out:
#        Unnamed: 0   Date  Country   City  Killed  Injured  Description
# 0           False  False    False  False   False    False        False
# 1           False  False    False  False   False    False        False
# 2           False  False    False  False   False    False        False
# 3           False  False    False  False   False    False        False
# 4           False  False    False  False   False    False        False
# ...           ...    ...      ...    ...     ...      ...          ...
# 29359       False  False    False  False   False    False        False
# 29360       False  False    False  False   False    False        False
# 29361       False  False    False  False   False    False        False
# 29362       False  False    False  False   False    False        False
# 29363       False  False    False  False   False    False        False
#
# [29364 rows x 7 columns]

# %%
vs.isnull().sum()
# Out:
# Unnamed: 0     0
# Date           0
# Country        0
# City           0
# Killed         0
# Injured        0
# Description    1
# dtype: int64

# %%
vs.Date.head()
# Out:
# 0    2002-01-01
# 1    2002-01-01
# 2    2002-01-01
# 3    2002-01-02
# 4    2002-01-02
# Name: Date, dtype: object

# %%
vs.Date.tail()
# Out:
# 29359    2016-07-16
# 29360    2016-07-18
# 29361    2016-07-18
# 29362    2016-07-18
# 29363    2016-07-18
# Name: Date, dtype: object

# %%
vs.Country.head(4)
# Out:
# 0    Indonesia
# 1        India
# 2        India
# 3        India
# Name: Country, dtype: object

# %%
vs["Country"].head(5)
# Out:
# 0    Indonesia
# 1        India
# 2        India
# 3        India
# 4        India
# Name: Country, dtype: object

# %%
vs[["Country","City","Date"]].head(5)
# Out:
#      Country            City        Date
# 0  Indonesia            Palu  2002-01-01
# 1      India       Baramulla  2002-01-01
# 2      India         Poshkar  2002-01-01
# 3      India         Rajouri  2002-01-02
# 4      India  Jehangir Chowk  2002-01-02

# %%
vs.rename(columns={"Date":"Tarih","Country":"Ülke"}, inplace=True)

# %%
vs
# Out:
#        Unnamed: 0       Tarih        Ülke            City  Killed  Injured  \
# 0               1  2002-01-01   Indonesia            Palu       1        0
# 1               2  2002-01-01       India       Baramulla       1        0
# 2               3  2002-01-01       India         Poshkar       2        0
# 3               4  2002-01-02       India         Rajouri       6        9
# 4               5  2002-01-02       India  Jehangir Chowk       2       25
# ...           ...         ...         ...             ...     ...      ...
# 29359       29360  2016-07-16       Syria          Aleppo       5        9
# 29360       29361  2016-07-18       Syria          Aleppo       3       15
# 29361       29362  2016-07-18       Yemen         Mukalla      10       18
# 29362       29363  2016-07-18  Kazakhstan          Almaty       4        0
# 29363       29364  2016-07-18     Germany       Wuerzburg       0        5
#
#                                              Description
# ...

# %%
vs
# Out:
#        Unnamed: 0       Tarih        Ülke            City  Killed  Injured  \
# 0               1  2002-01-01   Indonesia            Palu       1        0
# 1               2  2002-01-01       India       Baramulla       1        0
# 2               3  2002-01-01       India         Poshkar       2        0
# 3               4  2002-01-02       India         Rajouri       6        9
# 4               5  2002-01-02       India  Jehangir Chowk       2       25
# ...           ...         ...         ...             ...     ...      ...
# 29359       29360  2016-07-16       Syria          Aleppo       5        9
# 29360       29361  2016-07-18       Syria          Aleppo       3       15
# 29361       29362  2016-07-18       Yemen         Mukalla      10       18
# 29362       29363  2016-07-18  Kazakhstan          Almaty       4        0
# 29363       29364  2016-07-18     Germany       Wuerzburg       0        5
#
#                                              Description
# ...

# %%
vs.head(3)
# Out:
#    Unnamed: 0       Tarih       Ülke       City  Killed  Injured  \
# 0           1  2002-01-01  Indonesia       Palu       1        0
# 1           2  2002-01-01      India  Baramulla       1        0
# 2           3  2002-01-01      India    Poshkar       2        0
#
#                                          Description
# 0  Four bombs explode at Christian churches and o...
# 1  Terrorists enter the home of a civilian and ki...
# 2  Two civilians are abducted from their homes th...

# %%
vs.iloc[0,[3,2]]
# Out:
# City         Palu
# Ülke    Indonesia
# Name: 0, dtype: object

# %%
vs.iloc[0:5,[1,2,3]]
# Out:
#         Tarih       Ülke            City
# 0  2002-01-01  Indonesia            Palu
# 1  2002-01-01      India       Baramulla
# 2  2002-01-01      India         Poshkar
# 3  2002-01-02      India         Rajouri
# 4  2002-01-02      India  Jehangir Chowk

# %%
vs.iloc[0:5,0:4]
# Out:
#    Unnamed: 0       Tarih       Ülke            City
# 0           1  2002-01-01  Indonesia            Palu
# 1           2  2002-01-01      India       Baramulla
# 2           3  2002-01-01      India         Poshkar
# 3           4  2002-01-02      India         Rajouri
# 4           5  2002-01-02      India  Jehangir Chowk

# %%
vs.loc[29360,"Tarih":"Description"]
# Out:
# Tarih                                                 2016-07-18
# Ülke                                                       Syria
# City                                                      Aleppo
# Killed                                                         3
# Injured                                                       15
# Description    Sunnis send rockets into a residential neighbo...
# Name: 29360, dtype: object

# %%
vs.head(2)
# Out:
#    Unnamed: 0       Tarih       Ülke       City  Killed  Injured  \
# 0           1  2002-01-01  Indonesia       Palu       1        0
# 1           2  2002-01-01      India  Baramulla       1        0
#
#                                          Description
# 0  Four bombs explode at Christian churches and o...
# 1  Terrorists enter the home of a civilian and ki...

# %%
vs.shape
# Out:
# (29364, 7)

# %%
vs.dropna(axis="columns", how="any").shape
# Out:
# (29364, 6)

# %%
vs.Killed.value_counts()
# Out:
# 1      8907
# 2      5132
# 3      3129
# 4      2234
# 5      1518
#        ...
# 145       1
# 209       1
# 600       1
# 344       1
# 127       1
# Name: Killed, Length: 171, dtype: int64

# %%
vs.head(5)
# Out:
#    Unnamed: 0       Tarih       Ülke            City  Killed  Injured  \
# 0           1  2002-01-01  Indonesia            Palu       1        0
# 1           2  2002-01-01      India       Baramulla       1        0
# 2           3  2002-01-01      India         Poshkar       2        0
# 3           4  2002-01-02      India         Rajouri       6        9
# 4           5  2002-01-02      India  Jehangir Chowk       2       25
#
#                                          Description
# 0  Four bombs explode at Christian churches and o...
# 1  Terrorists enter the home of a civilian and ki...
# 2  Two civilians are abducted from their homes th...
# 3  Three separate terror attacks in the district ...
# 4  A Muslim militant kills two and injures twenty...

# %%
vs[vs.Tarih=="Ülke"].Killed.value_counts()
# Out:
# Series([], Name: Killed, dtype: int64)

# %%
vs.groupby("Tarih").Killed.value_counts(normalize=True)
# Out:
# Tarih       Killed
# 2002-01-01  1         0.666667
#             2         0.333333
# 2002-01-02  2         0.500000
#             6         0.500000
# 2002-01-03  1         1.000000
#                         ...
# 2016-07-16  3         0.166667
# 2016-07-18  0         0.250000
#             3         0.250000
#             4         0.250000
#             10        0.250000
# Name: Killed, Length: 20489, dtype: float64

# %%
vs.Tarih.str.slice(0,4).value_counts()
# Out:
# 2014    3013
# 2015    2893
# 2013    2846
# 2007    2658
# 2012    2559
# 2006    2286
# 2011    2043
# 2008    2029
# 2009    1942
# 2010    1926
# 2005    1534
# 2016    1300
# 2004     981
# 2003     790
# 2002     564
# Name: Tarih, dtype: int64

# %%
vs.dtypes
# Out:
# Unnamed: 0      int64
# Tarih          object
# Ülke           object
# City           object
# Killed          int64
# Injured         int64
# Description    object
# dtype: object

# %%
vs["Description"]=vs.Description.astype(bool)

# %%
vs.dtypes
# Out:
# Unnamed: 0      int64
# Tarih          object
# Ülke           object
# City           object
# Killed          int64
# Injured         int64
# Description      bool
# dtype: object

# %%
vs.head(2)
# Out:
#    Unnamed: 0       Tarih       Ülke       City  Killed  Injured  Description
# 0           1  2002-01-01  Indonesia       Palu       1        0         True
# 1           2  2002-01-01      India  Baramulla       1        0         True

# %%
vs.Killed.value_counts()
# Out:
# 1      8907
# 2      5132
# 3      3129
# 4      2234
# 5      1518
#        ...
# 145       1
# 209       1
# 600       1
# 344       1
# 127       1
# Name: Killed, Length: 171, dtype: int64

# %%
vs.Killed.mean()
# Out:
# 6.65982155019752

# %%
vs.groupby("Tarih").Injured.mean()
# Out:
# Tarih
# 2002-01-01     0.000000
# 2002-01-02    17.000000
# 2002-01-03     0.000000
# 2002-01-04     0.000000
# 2002-01-05     3.000000
#                 ...
# 2016-07-13     5.800000
# 2016-07-14    42.200000
# 2016-07-15     1.750000
# 2016-07-16     2.833333
# 2016-07-18     9.500000
# Name: Injured, Length: 5173, dtype: float64

# %%
# %matplotlib inline

# %%
vs.groupby("Tarih").Injured.mean().plot()
# Out:
# <AxesSubplot:xlabel='Tarih'>
